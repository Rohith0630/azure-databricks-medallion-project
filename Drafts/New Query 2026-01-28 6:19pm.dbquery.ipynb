-- %%
-- This verifies the compute is active and working
SELECT current_timestamp(), "Serverless Test Successful" as status;

-- Try creating a database for your F1 project
CREATE DATABASE IF NOT EXISTS f1_processed;
